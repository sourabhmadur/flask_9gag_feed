# %%
RSS_FEEDS = {'9gag': 'https://9gag-rss.com/api/rss/get?code=9GAGAwesome&format=2',
             'cnn': 'http://rss.cnn.com/rss/edition.rss',
             'fox': 'http://feeds.foxnews.com/foxnews/latest',
             'iol': 'http://www.iol.co.za/cmlink/1.640'}

# %%
import feedparser
from flask import Flask

# %%
feed = feedparser.parse(RSS_FEEDS['9gag'])

# %%
feed.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %%
feed.entries[1]
# Out:
# {'id': 'https://9gag.com/gag/aA3mEOL',
#  'guidislink': False,
#  'authors': [{'email': 'noreply@9gag-rss.com'}],
#  'author': 'noreply@9gag-rss.com',
#  'author_detail': {'email': 'noreply@9gag-rss.com'},
#  'title': 'Chiba, Japan',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'https://9gag-rss.com/api/rss/get?code=9GAGAwesome&format=2',
#   'value': 'Chiba, Japan'},
#  'summary': '<a href="http://9gag.com/gag/aA3mEOL"><img src="https://img-9gag-fun.9cache.com/photo/aA3mEOL_460s.jpg" /></a>',
#  'summary_detail': {'type': 'text/html',
#   'language': None,
#   'base': 'https://9gag-rss.com/api/rss/get?code=9GAGAwesome&format=2',
#   'value': '<a href="http://9gag.com/gag/aA3mEOL"><img src="https://img-9gag-fun.9cache.com/photo/aA3mEOL_460s.jpg" /></a>'},
#  'links': [{'href': 'http://9gag.com/gag/aA3mEOL',
#    'rel': 'alternate',
#    'type': 'text/html'}],
#  'link': 'http://9gag.com/gag/aA3mEOL',
#  'updated': '2019-04-29T23:42:02Z',
# ...

# %%
feed.entries[0].title
# Out:
# 'Hyper excited Puppies are instantly calmed down by their Mother'

# %%
feed.entries[0].updated
# Out:
# '2019-04-29T23:42:02Z'

# %%
feed.entries[0].title
# Out:
# 'Hyper excited Puppies are instantly calmed down by their Mother'

# %%
d = feedparser.parse('https://9gag-rss.com/api/rss/get?code=9GAGAwesome&format=2')

# %%
d['entries'][0].keys()
# Out:
# dict_keys(['id', 'guidislink', 'authors', 'author', 'author_detail', 'title', 'title_detail', 'summary', 'summary_detail', 'links', 'link', 'updated', 'updated_parsed'])

# %%
d.feed.title
# Out:
# '9GAG - Awesome'

# %%
d
# Out:
# {'feed': {'title': '9GAG - Awesome',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://9gag-rss.com/api/rss/get?code=9GAGAwesome&format=2',
#    'value': '9GAG - Awesome'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://9gag-rss.com/'}],
#   'link': 'https://9gag-rss.com/',
#   'subtitle': '9GAG - Awesome',
#   'subtitle_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://9gag-rss.com/api/rss/get?code=9GAGAwesome&format=2',
#    'value': '9GAG - Awesome'},
#   'authors': [{'email': 'noreply@9gag-rss.com'}],
#   'author': 'noreply@9gag-rss.com',
#   'author_detail': {'email': 'noreply@9gag-rss.com'},
#   'updated': 'Mon, 29 Apr 2019 23:54:01 Z',
#   'updated_parsed': time.struct_time(tm_year=2019, tm_mon=4, tm_mday=29, tm_hour=23, tm_min=54, tm_sec=1, tm_wday=0, tm_yday=119, tm_isdst=0),
#   'id': 'https://9gag-rss.com',
#   'guidislink': False},
# ...

# %%
d.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %%
d.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'subtitle', 'subtitle_detail', 'authors', 'author', 'author_detail', 'updated', 'updated_parsed', 'id', 'guidislink'])

# %%
d.entries[0].summary
# Out:
# '<div>\n\t                        <video preload="auto" poster="https://img-9gag-fun.9cache.com/photo/aZLdwv3_460s.jpg" width="460px" loop muted autoplay="autoplay" controls="controls">\n                                <source src="https://img-9gag-fun.9cache.com/photo/aZLdwv3_460sv.mp4" type="video/mp4">\n                                <source src="https://img-9gag-fun.9cache.com/photo/aZLdwv3_460svwm.webm" type="video/webm">\n                            </video>\n                        </div>'
